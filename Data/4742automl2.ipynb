# %%
# !pip install pandas pyarrow

# %%
import pandas as pd

# %%
data = pd.read_parquet('MF_LargeCap_Categories.parquet')
data
# Out:
#                             B42                  B45   B50   B56  \
# Month
# 2000-01  US Fund Mid-Cap Growth  US Fund Large Value  None  None
# 2000-02  US Fund Mid-Cap Growth  US Fund Large Value  None  None
# 2000-03  US Fund Mid-Cap Growth  US Fund Large Value  None  None
# 2000-04  US Fund Mid-Cap Growth  US Fund Large Value  None  None
# 2000-05  US Fund Mid-Cap Growth  US Fund Large Value  None  None
# ...                         ...                  ...   ...   ...
# 2021-04                    None                 None  None  None
# 2021-05                    None                 None  None  None
# 2021-06                    None                 None  None  None
# 2021-07                    None                 None  None  None
# 2021-08                    None                 None  None  None
#
#                               B113                                   B209  \
# Month
# 2000-01                       None                                   None
# ...
