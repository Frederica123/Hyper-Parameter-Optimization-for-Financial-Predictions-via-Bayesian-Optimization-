# %%
import os
file = os.listdir('/home/ecbm4040/WM-SecuritySelection/MAB_pngs/ACQ1/3')
import matplotlib.pyplot as plt # plt 用于显示图片
import numpy as np
import matplotlib.image as mpimg

#img = mpimp.imread("c:/456.png",cv2.IMREAD_UNCHANGED)
fig = plt.figure(figsize=(18,23))
for i in range(len(file)):
    img=mpimg.imread('/home/ecbm4040/WM-SecuritySelection/MAB_pngs/ACQ1/3/' + str(i)+'.png')
    ax=fig.add_subplot(5,2,i+1)
    
    plt.xticks([])
    plt.yticks([])
    for pos in ["left","right","bottom","top"]:
        ax.spines[pos].set_visible(False)
    ax.imshow(img)
    
        #print(i)

# %%
# !pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
# !pip install --upgrade pip
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 5.1 MB/s eta 0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# ...
